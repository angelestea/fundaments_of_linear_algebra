# %%
# %matplotlib notebook

import numpy as np
import matplotlib.pyplot as plt

# %%
v1 = np.array([1,1])
v2 = np.array([-1,-1])

fig = plt.figure()
ax=fig.add_subplot(111, projection='3d')
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">

# %%
v1 = np.array([1,1])
v2 = np.array([-1,-1])

fig = plt.figure()
ax=fig.add_subplot(111, projection='3d')

for a in range(-10,10):
    for b in range(-10,10):
        plt.scatter(v1[0]*a +v2[0]*b, v1[1]*a+v2[1]*b,
                    v1[2]*a+v2[2]*b,
                   marker = '.',
                   color='orange')
        
ax.set_xlabel('Eje x')
ax.set_ylabel('Eje y')
ax.set_zlabel('Eje z')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14476/2354906463.py in <module>
#       8     for b in range(-10,10):
#       9         plt.scatter(v1[0]*a +v2[0]*b, v1[1]*a+v2[1]*b,
# ---> 10                     v1[2]*a+v2[2]*b,
#      11                    marker = '.',
#      12                    color='orange')
#
# IndexError: index 2 is out of bounds for axis 0 with size 2

# %%
v1 = np.array([1,0])
v2=np.array([2,-3])

# %%
for a in range(-10,10):
    for b in range(-10,10):
        plt.scatter(v1[0]*a +v2[0]*b, v1[1]*a+v2[1]*b,
                   marker = '.',
                   color='orange')
        
plt.xlim(-25,25)
plt.ylim(-25,25)

plt.axvline(x=0, color = "grey")
plt.axhline(y=0, color = "grey")

plt.show()

# %%
from mpl_toolkits.mplot3d import Axes3D

v1= np.array([1,0,0])
v2=np.array([2,-3,0])

# %%
from mpl_toolkits.mplot3d import Axes3D

v1 = np.array([1, 0, 0])
v2 = np.array([2, -3, 0])

fig = plt.figure()
ax=fig.add_subplot(111, projection='3d')

for a in range(-10,10):
    for b in range(-10,10):
        plt.scatter(v1[0]*a +v2[0]*b, v1[1]*a+v2[1]*b,
                    v1[2]*a+v2[2]*b,
                   marker = '.',
                   color='orange')
        
ax.set_xlabel('Eje x')
ax.set_ylabel('Eje y')
ax.set_zlabel('Eje z')

plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640.0000169542105">

# %%
from mpl_toolkits.mplot3d import Axes30
v1 = np.array([1, e, e])
v2 = np. array([2, -3, 0])
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
    
for a in range(-10,10):
    for b in range(-10,10):
        ax.scatter(v1[[0]*a+ v2[0]*b, v1[1]*a + v2[1]*b,
                   v1[2]*a + v2[2]*b,
                   marker='.',
                   color = "orange")
                                           
ax.set_xlabel('Eje X')
ax.set_ylabel('Eje Y')
ax.set_zlabel('Eje Z')
plt.show()
# Out:
#   File "C:\Users\PC\AppData\Local\Temp/ipykernel_14476/3748788121.py", line 11
#     marker='.',
#           ^
# SyntaxError: invalid syntax

# %%
from mpl_toolkits.mplot3d import Axes3D
v1 - np.array([1, 0, 0])
v2 = np.array([2, -3, 0])
fig=plt.figure()
ax = fig.add_subplot(111, projection='3d')
for a in range(-10,10):
    for b in range(-10,10):
        ax.scatter(v1[0]*a+ v2[0]*b, v1[1]*a + v2[1]*b,
                    v1[2]*a + v2[2]*b,
                    marker ='.',
                  color = "orange")
ax.set_xlabel('Eje X')
ax.set_ylabel('Eje Y')
ax.set_zlabel('Eje z')
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="640">
